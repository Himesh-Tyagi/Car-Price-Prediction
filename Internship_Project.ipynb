# %%
import pandas as pd               # fo data analysis
import numpy as np                # for maths operations
import seaborn as sns             # data visualization
import matplotlib.pyplot as plt   # df #work like for matlab
df=pd.read_csv("car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df=df.drop(columns=['Car_Name'])
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %% [markdown]
# # QUESTION 1:- CLEAN THE DATA

# %%
df.head(10)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
# 5  2018           9.25           9.83        2071    Diesel      Dealer
# 6  2015           6.75           8.12       18796    Petrol      Dealer
# 7  2015           6.50           8.61       33429    Diesel      Dealer
# 8  2016           8.75           8.89       20273    Diesel      Dealer
# 9  2015           7.45           8.92       42367    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0
# 5       Manual      0
# ...

# %%
df.tail(10)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 291  2015           5.40           6.10       31427    Petrol      Dealer
# 292  2016           6.40           8.40       12000    Petrol      Dealer
# 293  2010           3.25           9.90       38000    Petrol      Dealer
# 294  2014           3.75           6.80       33019    Petrol      Dealer
# 295  2015           8.55          13.09       60076    Diesel      Dealer
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 291       Manual      0
# 292       Manual      0
# 293       Manual      0
# 294       Manual      0
# 295       Manual      0
# ...

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.shape
# Out:
# (301, 8)

# %%
print(df['Seller_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.size
# Out:
# 2408

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           299 non-null    int64
#  1   Selling_Price  299 non-null    float64
#  2   Present_Price  299 non-null    float64
#  3   Kms_Driven     299 non-null    int64
#  4   Fuel_Type      299 non-null    object
#  5   Seller_Type    299 non-null    object
#  6   Transmission   299 non-null    object
#  7   Owner          299 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 21.0+ KB

# %%
df.isnull().sum() # missing values
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#[Make a new column and set current year 2024 then find number of year.]
# Set the current year
currentyear = 2024

# Calculate the car's age
df['Car_Age'] = currentyear - df['Year']
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Car_Age
# 0         Manual      0       10
# ...

# %%
year_wise=df.Year.value_counts()
year_wise
# Out:
# Year
# 2015    60
# 2016    49
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
dff=df.select_dtypes(include=['object']).columns.tolist() # all  CATEGORICAL( words data ) VARIABLES
dff
# Out:
# ['Fuel_Type', 'Seller_Type', 'Transmission']

# %%
numeric_df = df.select_dtypes(include=[np.number]) # collect all numeric value for handling the outliers
numeric_df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Car_Age
# 0    2014           3.35           5.59       27000      0       10
# 1    2013           4.75           9.54       43000      0       11
# 2    2017           7.25           9.85        6900      0        7
# 3    2011           2.85           4.15        5200      0       13
# 4    2014           4.60           6.87       42450      0       10
# ..    ...            ...            ...         ...    ...      ...
# 296  2016           9.50          11.60       33988      0        8
# 297  2015           4.00           5.90       60000      0        9
# 298  2009           3.35          11.00       87934      0       15
# 299  2017          11.50          12.50        9000      0        7
# 300  2016           5.30           5.90        5464      0        8
#
# [299 rows x 6 columns]

# %%
# Identify outliers using box plot
# for all numericals data columns 

plt.figure(figsize=(9,7)) # size of figure
figure=df.boxplot(column="Year")

# %%
plt.figure(figsize=(9,7)) # size of figure
figure=df.boxplot(column="Selling_Price")

# %%
plt.figure(figsize=(12,5)) # size of figure
figure=df.boxplot(column="Present_Price")

# %%
plt.figure(figsize=(8,5)) # size of figure
figure=df.boxplot(column="Kms_Driven")

# %%
plt.figure(figsize=(8,5)) # size of figure
figure=df.boxplot(column="Owner")

# %%
plt.figure(figsize=(8,5)) # size of figure
figure=df.boxplot(column="Car_Age")

# %%
#handling outliers i.e. finish all outliers
Q1=numeric_df.quantile(0.25).round(3)  # taking lower quantile into q2
Q3=numeric_df.quantile(0.75).round(3)  # taking upper quantile into q2
IQR=Q3-Q1                              # calculating inter quantile range
print(IQR)                             # printing quantile range
# Out:
# Year                 4.00
# Selling_Price        5.15
# Present_Price        8.64
# Kms_Driven       33883.50
# Owner                0.00
# Car_Age              4.00
# dtype: float64

# %%
dfout=numeric_df[~((numeric_df<(Q1-1.5*IQR))|(numeric_df>(Q3+1.5*IQR))).any(axis=1)]
dfout.shape
# Out:
# (262, 6)

# %% [markdown]
# # sanity check means outliers are remove or not

# %%
sns.boxplot(x=dfout['Year'])
# Out:
# <Axes: xlabel='Year'>

# %%
sns.boxplot(x=dfout['Selling_Price'])
# Out:
# <Axes: xlabel='Selling_Price'>

# %%
sns.boxplot(x=dfout['Present_Price'])
# Out:
# <Axes: xlabel='Present_Price'>

# %% [markdown]
# #2.Perform EDA :-# Histograms and  Boxplots for numerical columns
#                 # Bar plots for categorical columns

# %%
#Hstogram for all numeric values/columns
numeric_df.hist(bins=20,figsize=(20, 15),color='red')
plt.show()

# %%
#Boxplots for numerical columns 
plt.figure(figsize=(15, 10))
sns.boxplot(data=df.select_dtypes(include=['float64', 'int64']))
plt.show()

# %%
#Bar plots for categorical columns

# %%
plt.figure(figsize=(10,5))
plt.style.use('classic')
ax=sns.countplot(x="Fuel_Type",data=df,palette="tab10")
ax.set_xlabel(xlabel="Fuel_Type" ,fontsize=30)
# Out:
# C:\Users\DELL PC\AppData\Local\Temp\ipykernel_11064\1548529876.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x="Fuel_Type",data=df,palette="tab10")
# Text(0.5, 0, 'Fuel_Type')

# %%
plt.figure(figsize=(10,5))
plt.style.use('classic')
ax=sns.countplot(x="Seller_Type",data=df,palette="tab10")
ax.set_xlabel(xlabel="Seller_Type" ,fontsize=30)
# Out:
# C:\Users\DELL PC\AppData\Local\Temp\ipykernel_11064\1900476583.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x="Seller_Type",data=df,palette="tab10")
# Text(0.5, 0, 'Seller_Type')

# %%
plt.figure(figsize=(10,5))
plt.style.use('classic')
ax=sns.countplot(x="Transmission",data=df,palette="tab10")
ax.set_xlabel(xlabel="Transmission" ,fontsize=30)
# Out:
# C:\Users\DELL PC\AppData\Local\Temp\ipykernel_11064\2799237883.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x="Transmission",data=df,palette="tab10")
# Text(0.5, 0, 'Transmission')

# %% [markdown]
# #3.Try different suitable Machine Learning Techqniues.

# %%
# Convert categorical variables to numeric using one-hot encoding
df = pd.get_dummies(df, drop_first=True)
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Car_Age  \
# 0    2014           3.35           5.59       27000      0       10
# 1    2013           4.75           9.54       43000      0       11
# 2    2017           7.25           9.85        6900      0        7
# 3    2011           2.85           4.15        5200      0       13
# 4    2014           4.60           6.87       42450      0       10
# ..    ...            ...            ...         ...    ...      ...
# 296  2016           9.50          11.60       33988      0        8
# 297  2015           4.00           5.90       60000      0        9
# 298  2009           3.35          11.00       87934      0       15
# 299  2017          11.50          12.50        9000      0        7
# 300  2016           5.30           5.90        5464      0        8
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# ...

# %%
from sklearn.preprocessing import LabelEncoder
x=df.drop(['Selling_Price'],axis=1) # drop high corelated features
x # new data set
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Car_Age  Fuel_Type_Diesel  \
# 0    2014           5.59       27000      0       10             False
# 1    2013           9.54       43000      0       11              True
# 2    2017           9.85        6900      0        7             False
# 3    2011           4.15        5200      0       13             False
# 4    2014           6.87       42450      0       10              True
# ..    ...            ...         ...    ...      ...               ...
# 296  2016          11.60       33988      0        8              True
# 297  2015           5.90       60000      0        9             False
# 298  2009          11.00       87934      0       15             False
# 299  2017          12.50        9000      0        7              True
# 300  2016           5.90        5464      0        8             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# ...

# %%
y=df['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
from sklearn.model_selection import train_test_split  # split x & y into training and testing sets
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Car_Age  Fuel_Type_Diesel  \
# 6    2015           8.12       18796      0        9             False
# 185  2008           0.58        1900      0       16             False
# 187  2013           0.51       32000      0       11             False
# 148  2010           0.94       45000      0       14             False
# 31   2011           4.89       54200      0       13             False
# ..    ...            ...         ...    ...      ...               ...
# 190  2008           0.75       60000      0       16             False
# 72   2013          18.61       56001      0       11             False
# 108  2016           1.50       18000      0        8             False
# 272  2015          10.00       27600      0        9             False
# 104  2017           1.47        4100      0        7             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# ...

# %%
y_train
# Out:
# 6      6.75
# 185    0.25
# 187    0.25
# 148    0.52
# 31     2.35
#        ...
# 190    0.20
# 72     7.45
# 108    1.20
# 272    7.50
# 104    1.35
# Name: Selling_Price, Length: 239, dtype: float64

# %%
x_test
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Car_Age  Fuel_Type_Diesel  \
# 283  2016         11.800        9010      0        8             False
# 267  2016          9.400       19434      0        8              True
# 166  2016          0.550        1000      0        8             False
# 9    2015          8.920       42367      0        9              True
# 78   2010         22.830       80000      0       14             False
# 280  2015          5.900       14465      0        9             False
# 95   2012         18.610       72000      0       12             False
# 111  2016          1.500        8700      0        8             False
# 5    2018          9.830        2071      0        6              True
# 175  2011          0.787       75000      0       13             False
# 99   2010         20.450       50024      0       14              True
# 197  2010          0.510       33000      0       14             False
# ...

# %%
y_test
# Out:
# 283     8.99
# 267     8.35
# 166     0.45
# 9       7.45
# 78      5.25
# 280     5.25
# 95      5.85
# 111     1.15
# 5       9.25
# 175     0.38
# 99      9.65
# 197     0.16
# 186     0.25
# 156     0.48
# 58      4.10
# 61      4.50
# 149     0.51
# 110     1.20
# 64     33.00
# 142     0.60
# 157     0.48
# 106     1.35
# 249     5.25
# 47      1.05
# 43      5.50
# 277     9.70
# 282     8.25
# 118     1.10
# 215     4.50
# 238     4.80
# 18      3.25
# 241     4.75
# 34      5.50
# 25      3.00
# 46      2.65
# 7       6.50
# 115     1.11
# 196     0.17
# 113     1.15
# 94      4.00
# 76      5.50
# 83     12.50
# 120     1.05
# 77      1.50
# 131     0.75
# 199     0.12
# 212    11.25
# 290     4.50
# 221     4.50
# 180     0.30
# 146     0.55
# 188     0.25
# 85      2.50
# 250    12.90
# 279     6.25
# 74      4.90
# 246     3.75
# 26      4.15
# 211    11.75
# 60      6.95
# Name: Selling_Price, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor(max_depth=3)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
print(dt.score(x_train,y_train))
print(dt.score(x_test, y_test))
# Out:
# 0.9008772523072345
# 0.55094830051856

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error

model_lr= LinearRegression()
model_lr.fit(x_train,y_train)

#make predicton
y_pred_lr=model_lr.predict(x_test)

# calculate performance metrics
mae_lr=mean_absolute_error(y_test,y_pred_lr)
mse_lr=mean_squared_error(y_test,y_pred_lr)
rmse_lr=np.sqrt(mse_lr)
mape_lr=np.mean(np.abs((y_test-y_pred_lr)/np.abs(y_test)))
accuracy_lr=100*(1-mape_lr)


#print the performance
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE)')
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
print('Accuracy:', round(accuracy_lr, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE)
# Mean Squared Error (MSE): 6.370752956827596
# Root Mean Squared Error (RMSE): 2.524035054595636
# Mean Absolute Percentage Error (MAPE): 148.0
# Accuracy: -48.0

# %%
from sklearn.tree import DecisionTreeRegressor # decision tree
from sklearn.metrics import mean_absolute_error,mean_squared_error

# create and train the dicision tree model
model= DecisionTreeRegressor()
model.fit(x_train,y_train)

#make predicton
y_pred=model.predict(x_test)

# calculate performance metrics
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mape=np.mean(np.abs((y_test-y_pred)/np.abs(y_test)))
accuracy=100*(1-mape)

#print the performance
print('Mean Absolute Error (MAE):' ,mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 1.0521666666666667
# Mean Squared Error (MSE): 3.9724149999999994
# Root Mean Squared Error (RMSE): 1.9930918192597147
# Mean Absolute Percentage Error (MAPE): 30.0
# Accuracy: 70.0

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_squared_error

# Create and train the Random Forest model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

# Calculate performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

# Print the performance
print('Random Forest Metrics:')
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape_rf * 100, 2))
print('Accuracy:', round(accuracy_rf, 2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error (MAE): 1.5144433333333347
# Mean Squared Error (MSE): 13.389814074000013
# Root Mean Squared Error (RMSE): 3.6592094875806187
# Mean Absolute Percentage Error (MAPE): 38.94
# Accuracy: 61.06

# %%
import xgboost as xgb

# Create and train the Linear Regression model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb = 100 * (1 - mape_xgb)

# Print the performance metrics for Linear Regression
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape_xgb * 100, 2))
print('Accuracy:', round(accuracy_xgb, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 1.0801395116845767
# Mean Squared Error (MSE): 5.403750227252583
# Root Mean Squared Error (RMSE): 2.3245967881016663
# Mean Absolute Percentage Error (MAPE): 29.92
# Accuracy: 70.08

# %%
import  pickle 
from xgboost import XGBRegressor


# example :train a model 
model_xgb=XGBRegressor()
model_xgb.fit(x_train,y_train)

#save the trained model to file using pickle
with open ('car.pkl','wb')as file:
 pickle.dump(model_xgb,file)

print("model saved successfully")
# Out:
# model saved successfully

# %%
streamlit_code = """

import streamlit as st
import pickle
import numpy as np
import pandas as pd

# Load the trained model and scaler
with open('car.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

# Streamlit app
st.title("Car Price Prediction")
st.header("Input Features")


# Sidebar inputs
year = st.slider("Year", min_value=2000, max_value=2022, value=2015)
present_price = st.number_input("Present Price (in lakhs)", min_value=0.0, value=6.0)
kms_driven = st.number_input("Kms Driven", min_value=0)
fuel_type = st.selectbox("Fuel Type", ['Petrol', 'Diesel', 'CNG'])
seller_type = st.selectbox("Seller Type", ['Dealer', 'Individual'])
transmission = st.radio("Transmission", ['Manual', 'Automatic'])
owner = st.slider("Owner", min_value=0, max_value=3, value=0)
Car_Age = st.slider("Car Age", min_value=1, max_value=20, value=5)

# Create input DataFrame with correct feature names and order
input_data = pd.DataFrame({
    'Year': [year],
    'Present_Price': [present_price],
    'Kms_Driven': [kms_driven],
    'Owner': [owner],
    'Car_Ager': [Car_Age],
    'Fuel_Type': [fuel_type],
    'Seller_Type': [seller_type],
    'Transmission': [transmission]
})

# Map categorical variables to dummy variables
input_data = pd.get_dummies(input_data, drop_first=True)

# Ensure all required columns are present and in the correct order
expected_columns = ['Year', 'Present_Price', 'Kms_Driven', 'Owner', 'Car_Age',
                    'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual', 'Transmission_Manual']

# Reorder columns to match the expected order
input_data = input_data.reindex(columns=expected_columns, fill_value=0)

# Make prediction
predicted_price = model.predict(input_data)

# Display prediction
st.write(f"Predicted Selling Price:   {predicted_price[0]:.2f} lakhs")
"""
# Specify the file path where the hrapp.py file will be saved
file_path = 'carapp.py'

# Write the content to the file
with open(file_path, 'w') as file:
    file.write(streamlit_code)

print(f"File '{file_path}' has been saved.")
# Out:
# File 'carapp.py' has been saved.
